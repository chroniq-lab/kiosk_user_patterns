# %%
import sys
from pathlib import Path
import pyarrow.parquet as pq
import pyarrow.dataset as ds
import pandas as pd
import matplotlib.pyplot as plt
sys.path.append(str(Path.cwd().parent))
from config import PATH_KIOSK_USER_PATTERNS_FOLDER, PATH_KIOSK_USER_PATTERNS_REPO, PATH_DATA_SHARING_FOLDER

# Example usage
kupdat03_path = PATH_DATA_SHARING_FOLDER /'DEWEY'
execfile(PATH_KIOSK_USER_PATTERNS_REPO / 'constants.py')

# %%
# data_endpoint = "https://app.deweydata.io/external-api/v3/products/c117bbd0-ed3a-4c05-8f3c-01ac4b12ef60/files"
data_endpoint = "https://app.deweydata.io/api/v1/external/data/fldr_rmdqcq7izzrebtakm"

# %%
# # https://consumer-docs.amplifydata.io/docs/download-all-files
# # set API URL
# execfile(PATH_KIOSK_USER_PATTERNS_REPO / 'functions' / 'make_get_request.py')
# PRODUCT_API_PATH = <URL generated by step 2>

# # get results from API endpoint, using API key for authentication
# results = make_get_request(
#     url=PRODUCT_API_PATH,
#     params={'page': 1, # only getting 1st page of results
#             'partition_key_after': '1900-01-01', # set min date value here
#             'partition_key_before': '2099-01-01'} # set max date value here
# )

# # loop through download links and save to your computer
# for i, link_data in enumerate(results.json()["download_links"]):
#     print(f"Downloading file {i}...")
#     data = requests.get(link_data["link"])
#     open(link_data["file_name"], 'wb').write(data.content)

# %%
# https://docs.deweydata.io/docs/api-access
import deweydatapy as ddp

# API Key
apikey = bulk_api_veraset_home_location

# Product path
pp_ = data_endpoint

meta = ddp.get_meta(apikey, pp_) # returns a dataframe with meta information
files = ddp.get_file_list(apikey, pp_)
# Out:
#
# Metadata summary ------------------------------------------------
# Total number of files: 1,013
# Total files size (MB): 253,923.91
# Date aggregation: None
# Date partition column: None
# Data min available date: None
# Data max available date: None
# -----------------------------------------------------------------
#
# Collecting files information for page 1/21...
# Collecting files information for page 2/21...
# Collecting files information for page 3/21...
# Collecting files information for page 4/21...
# Collecting files information for page 5/21...
# Collecting files information for page 6/21...
# Collecting files information for page 7/21...
# Collecting files information for page 8/21...
# Collecting files information for page 9/21...
# Collecting files information for page 10/21...
# Collecting files information for page 11/21...
# Collecting files information for page 12/21...
# Collecting files information for page 13/21...
# Collecting files information for page 14/21...
# Collecting files information for page 15/21...
# Collecting files information for page 16/21...
# Collecting files information for page 17/21...
# Collecting files information for page 18/21...
# Collecting files information for page 19/21...
# Collecting files information for page 20/21...
# Collecting files information for page 21/21...
# Files information collection completed.
#
# Files information summary ---------------------------------------
# Total number of pages: 21
# Total number of files: 1,013
# Total files size (MB): 253,923.91
# Average single file size (MB): 250.97
# Date partition column: None
# Expires at: 2025-07-11T15:40:34.786085+00:00
# -----------------------------------------------------------------

# %%
files.to_csv(PATH_KIOSK_USER_PATTERNS_REPO / 'data' / 'kupdat03a_veraset home location.csv', index=False)

# %%
files.head()
# Out:
#    index  page                                               link  \
# 0      0     1  https://app.deweydata.io/api/v1/downloads/0197...
# 1      1     1  https://app.deweydata.io/api/v1/downloads/0197...
# 2      2     1  https://app.deweydata.io/api/v1/downloads/0197...
# 3      3     1  https://app.deweydata.io/api/v1/downloads/0197...
# 4      4     1  https://app.deweydata.io/api/v1/downloads/0197...
#
#   partition_key                   file_name file_extension  file_size_bytes  \
# 0          None  home-location_0_0_0.csv.gz        .csv.gz        262158983
# 1          None  home-location_0_0_1.csv.gz        .csv.gz        262151517
# 2          None  home-location_0_0_2.csv.gz        .csv.gz        262157681
# 3          None  home-location_0_0_3.csv.gz        .csv.gz        262170901
# 4          None  home-location_0_0_4.csv.gz        .csv.gz        262173384
#
#                         modified_at  \
# 0  2025-06-30T15:13:30.720000+00:00
# 1  2025-06-30T15:14:20.954000+00:00
# 2  2025-06-30T15:15:16.827000+00:00
# 3  2025-06-30T15:16:22.320000+00:00
# 4  2025-06-30T15:17:18.643000+00:00
#
#                                  external_id  \
# 0  dwll_0197f4fe-e464-7130-bd58-d33385d6bcb2
# 1  dwll_0197f4fe-e464-7130-bd58-d34a630ee952
# 2  dwll_0197f4fe-e464-7130-bd58-d359f387bd42
# 3  dwll_0197f4fe-e464-7130-bd58-d36e6a9caf4d
# 4  dwll_0197f4fe-e464-7130-bd58-d37e53499417
#
#                                        download_link
# 0  https://app.deweydata.io/api/v1/downloads/0197...
# 1  https://app.deweydata.io/api/v1/downloads/0197...
# 2  https://app.deweydata.io/api/v1/downloads/0197...
# 3  https://app.deweydata.io/api/v1/downloads/0197...
# 4  https://app.deweydata.io/api/v1/downloads/0197...

# %%
files['link'][1]
# Out:
# 'https://app.deweydata.io/api/v1/downloads/0197f4fe-e464-7130-bd58-d34a630ee952/link'

# %%
ddp.read_sample(files['link'][1])
# Out:
#                                                  CAID  CENSUS_BLOCK_GROUP  \
# 0   34d072a70d6b4ab64bf4cf614f4bde29ff8cc8998291d6...        361031245004
# 1   257428e197bcad56be5df518164a8ad3ad7044b5ceae1f...        470279551001
# 2   9a592b141e77d3579d6b03cfca6d437ed69bad01df69f7...        170438464123
# 3   d172cfde7e5877b12c489ba78ed7dcf939ea36e918c987...        482012333003
# 4   53409894b24ce632069c302aeec547be54de673fcb65ae...        291833103022
# ..                                                ...                 ...
# 95  a572a10fd49eab56a02e13aee0835dd097fc9c06e77d77...        361190148094
# 96  4a8692bb293969df59f1f7f6e08ccf91346dc872207fc9...        360810645001
# 97  5ca0ddd30604f789d778ec2b90a178609dda886c48e6fa...        201799526002
# 98  feecf70463473ffa54588f26bb692d3d1e6ca008f8a844...        230310235005
# 99  e41811a25620d88f4f459e27b4342c45aaba3b6c30df92...        180159593001
#
#            CITY                   COUNTRY  GEO_HASH5     REGION  ZIP_CODE
# 0       babylon  united states of america        NaN   new york       NaN
# 1           NaN  united states of america        NaN  tennessee       NaN
# 2    naperville  united states of america        NaN   illinois       NaN
# 3       houston  united states of america        NaN      texas       NaN
# 4   st. charles  united states of america        NaN   missouri       NaN
# ..          ...                       ...        ...        ...       ...
# 95     yorktown  united states of america        NaN   new york       NaN
# 96     new york  united states of america        NaN   new york       NaN
# 97       selden  united states of america        NaN     kansas       NaN
# 98    shapleigh  united states of america        NaN      maine       NaN
# 99          NaN  united states of america        NaN    indiana       NaN
#
# [100 rows x 7 columns]

# %%
files[files['index'] == 1]
# Out:
#    index  page                                               link  \
# 1      1     1  https://app.deweydata.io/api/v1/downloads/0197...
#
#   partition_key                   file_name file_extension  file_size_bytes  \
# 1          None  home-location_0_0_1.csv.gz        .csv.gz        262151517
#
#                         modified_at  \
# 1  2025-06-30T15:14:20.954000+00:00
#
#                                  external_id  \
# 1  dwll_0197f4fe-e464-7130-bd58-d34a630ee952
#
#                                        download_link
# 1  https://app.deweydata.io/api/v1/downloads/0197...

# %%
ddp.download_files(files, 
                    dest_folder = r'H:/data/DEWEY/Veraset/Home Location/',   skip_exists= True)
# Out:
# Downloading 1/1013 (file index = 0)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_0_0.csv.gz
# Skipping...
# Downloading 2/1013 (file index = 1)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_0_1.csv.gz
# Skipping...
# Downloading 3/1013 (file index = 2)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_0_2.csv.gz
# Skipping...
# Downloading 4/1013 (file index = 3)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_0_3.csv.gz
# Skipping...
# Downloading 5/1013 (file index = 4)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_0_4.csv.gz
# Skipping...
# Downloading 6/1013 (file index = 5)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_0_5.csv.gz
# Skipping...
# Downloading 7/1013 (file index = 6)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_0_6.csv.gz
# Skipping...
# Downloading 8/1013 (file index = 7)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_0_7.csv.gz
# Skipping...
# Downloading 9/1013 (file index = 8)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_1_0.csv.gz
# Skipping...
# Downloading 10/1013 (file index = 9)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_1_1.csv.gz
# Skipping...
# Downloading 11/1013 (file index = 10)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_1_2.csv.gz
# Skipping...
# Downloading 12/1013 (file index = 11)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_1_3.csv.gz
# Skipping...
# Downloading 13/1013 (file index = 12)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_1_4.csv.gz
# Skipping...
# Downloading 14/1013 (file index = 13)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_1_5.csv.gz
# Skipping...
# Downloading 15/1013 (file index = 14)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_1_6.csv.gz
# Skipping...
# Downloading 16/1013 (file index = 15)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_1_7.csv.gz
# Skipping...
# Downloading 17/1013 (file index = 16)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_2_0.csv.gz
# Skipping...
# Downloading 18/1013 (file index = 17)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_2_1.csv.gz
# Skipping...
# Downloading 19/1013 (file index = 18)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_2_2.csv.gz
# Skipping...
# Downloading 20/1013 (file index = 19)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_2_3.csv.gz
# Skipping...
# Downloading 21/1013 (file index = 20)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_2_4.csv.gz
# Skipping...
# Downloading 22/1013 (file index = 21)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_2_5.csv.gz
# Skipping...
# Downloading 23/1013 (file index = 22)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_2_6.csv.gz
# Skipping...
# Downloading 24/1013 (file index = 23)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_2_7.csv.gz
# Skipping...
# Downloading 25/1013 (file index = 24)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_3_0.csv.gz
# Skipping...
# Downloading 26/1013 (file index = 25)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_3_1.csv.gz
# Skipping...
# Downloading 27/1013 (file index = 26)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_3_2.csv.gz
# Skipping...
# Downloading 28/1013 (file index = 27)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_3_3.csv.gz
# Skipping...
# Downloading 29/1013 (file index = 28)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_3_4.csv.gz
# Skipping...
# Downloading 30/1013 (file index = 29)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_3_5.csv.gz
# Skipping...
# Downloading 31/1013 (file index = 30)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_3_6.csv.gz
# Skipping...
# Downloading 32/1013 (file index = 31)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_3_7.csv.gz
# Skipping...
# Downloading 33/1013 (file index = 32)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_4_0.csv.gz
# Skipping...
# Downloading 34/1013 (file index = 33)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_4_1.csv.gz
# Skipping...
# Downloading 35/1013 (file index = 34)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_4_2.csv.gz
# Skipping...
# Downloading 36/1013 (file index = 35)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_4_3.csv.gz
# Skipping...
# Downloading 37/1013 (file index = 36)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_4_4.csv.gz
# Skipping...
# Downloading 38/1013 (file index = 37)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_4_5.csv.gz
# Skipping...
# Downloading 39/1013 (file index = 38)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_4_6.csv.gz
# Skipping...
# Downloading 40/1013 (file index = 39)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_4_7.csv.gz
# Skipping...
# Downloading 41/1013 (file index = 40)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_5_0.csv.gz
# Skipping...
# Downloading 42/1013 (file index = 41)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_5_1.csv.gz
# Skipping...
# Downloading 43/1013 (file index = 42)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_5_2.csv.gz
# Skipping...
# Downloading 44/1013 (file index = 43)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_5_3.csv.gz
# Skipping...
# Downloading 45/1013 (file index = 44)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_5_4.csv.gz
# Skipping...
# Downloading 46/1013 (file index = 45)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_5_5.csv.gz
# Skipping...
# Downloading 47/1013 (file index = 46)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_5_6.csv.gz
# Skipping...
# Downloading 48/1013 (file index = 47)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_5_7.csv.gz
# Skipping...
# Downloading 49/1013 (file index = 48)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_6_0.csv.gz
# Skipping...
# Downloading 50/1013 (file index = 49)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_6_1.csv.gz
# Skipping...
# Downloading 51/1013 (file index = 50)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_6_2.csv.gz
# Skipping...
# Downloading 52/1013 (file index = 51)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_6_3.csv.gz
# Skipping...
# Downloading 53/1013 (file index = 52)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_6_4.csv.gz
# Skipping...
# Downloading 54/1013 (file index = 53)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_6_5.csv.gz
# Skipping...
# Downloading 55/1013 (file index = 54)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_6_6.csv.gz
# Skipping...
# Downloading 56/1013 (file index = 55)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_6_7.csv.gz
# Skipping...
# Downloading 57/1013 (file index = 56)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_7_0.csv.gz
# Skipping...
# Downloading 58/1013 (file index = 57)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_7_1.csv.gz
# Skipping...
# Downloading 59/1013 (file index = 58)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_7_2.csv.gz
# Skipping...
# Downloading 60/1013 (file index = 59)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_7_3.csv.gz
# Skipping...
# Downloading 61/1013 (file index = 60)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_7_4.csv.gz
# Skipping...
# Downloading 62/1013 (file index = 61)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_7_5.csv.gz
# Skipping...
# Downloading 63/1013 (file index = 62)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_7_6.csv.gz
# Skipping...
# Downloading 64/1013 (file index = 63)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_0_7_7.csv.gz
# Skipping...
# Downloading 65/1013 (file index = 64)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_0_0.csv.gz
# Skipping...
# Downloading 66/1013 (file index = 65)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_0_1.csv.gz
# Skipping...
# Downloading 67/1013 (file index = 66)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_0_2.csv.gz
# Skipping...
# Downloading 68/1013 (file index = 67)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_0_3.csv.gz
# Skipping...
# Downloading 69/1013 (file index = 68)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_0_4.csv.gz
# Skipping...
# Downloading 70/1013 (file index = 69)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_0_5.csv.gz
# Skipping...
# Downloading 71/1013 (file index = 70)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_0_6.csv.gz
# Skipping...
# Downloading 72/1013 (file index = 71)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_0_7.csv.gz
# Skipping...
# Downloading 73/1013 (file index = 72)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_0_0.csv.gz
# Skipping...
# Downloading 74/1013 (file index = 73)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_1_0.csv.gz
# Skipping...
# Downloading 75/1013 (file index = 74)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_1_1.csv.gz
# Skipping...
# Downloading 76/1013 (file index = 75)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_1_2.csv.gz
# Skipping...
# Downloading 77/1013 (file index = 76)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_1_3.csv.gz
# Skipping...
# Downloading 78/1013 (file index = 77)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_1_4.csv.gz
# Skipping...
# Downloading 79/1013 (file index = 78)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_1_5.csv.gz
# Skipping...
# Downloading 80/1013 (file index = 79)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_1_6.csv.gz
# Skipping...
# Downloading 81/1013 (file index = 80)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_1_7.csv.gz
# Skipping...
# Downloading 82/1013 (file index = 81)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_0_1.csv.gz
# Skipping...
# Downloading 83/1013 (file index = 82)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_2_0.csv.gz
# Skipping...
# Downloading 84/1013 (file index = 83)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_2_1.csv.gz
# Skipping...
# Downloading 85/1013 (file index = 84)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_2_2.csv.gz
# Skipping...
# Downloading 86/1013 (file index = 85)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_2_3.csv.gz
# Skipping...
# Downloading 87/1013 (file index = 86)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_2_4.csv.gz
# Skipping...
# Downloading 88/1013 (file index = 87)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_2_5.csv.gz
# Skipping...
# Downloading 89/1013 (file index = 88)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_2_6.csv.gz
# Skipping...
# Downloading 90/1013 (file index = 89)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_2_7.csv.gz
# Skipping...
# Downloading 91/1013 (file index = 90)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_0_2.csv.gz
# Skipping...
# Downloading 92/1013 (file index = 91)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_3_0.csv.gz
# Skipping...
# Downloading 93/1013 (file index = 92)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_3_1.csv.gz
# Skipping...
# Downloading 94/1013 (file index = 93)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_3_2.csv.gz
# Skipping...
# Downloading 95/1013 (file index = 94)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_3_3.csv.gz
# Skipping...
# Downloading 96/1013 (file index = 95)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_3_4.csv.gz
# Skipping...
# Downloading 97/1013 (file index = 96)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_3_5.csv.gz
# Skipping...
# Downloading 98/1013 (file index = 97)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_3_6.csv.gz
# Skipping...
# Downloading 99/1013 (file index = 98)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_3_7.csv.gz
# Skipping...
# Downloading 100/1013 (file index = 99)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_0_3.csv.gz
# Skipping...
# Downloading 101/1013 (file index = 100)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_4_0.csv.gz
# Skipping...
# Downloading 102/1013 (file index = 101)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_4_1.csv.gz
# Skipping...
# Downloading 103/1013 (file index = 102)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_4_2.csv.gz
# Skipping...
# Downloading 104/1013 (file index = 103)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_4_3.csv.gz
# Skipping...
# Downloading 105/1013 (file index = 104)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_4_4.csv.gz
# Skipping...
# Downloading 106/1013 (file index = 105)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_4_5.csv.gz
# Skipping...
# Downloading 107/1013 (file index = 106)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_4_6.csv.gz
# Skipping...
# Downloading 108/1013 (file index = 107)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_4_7.csv.gz
# Skipping...
# Downloading 109/1013 (file index = 108)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_0_4.csv.gz
# Skipping...
# Downloading 110/1013 (file index = 109)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_5_0.csv.gz
# Skipping...
# Downloading 111/1013 (file index = 110)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_5_1.csv.gz
# Skipping...
# Downloading 112/1013 (file index = 111)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_5_2.csv.gz
# Skipping...
# Downloading 113/1013 (file index = 112)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_5_3.csv.gz
# Skipping...
# Downloading 114/1013 (file index = 113)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_5_4.csv.gz
# Skipping...
# Downloading 115/1013 (file index = 114)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_5_5.csv.gz
# Skipping...
# Downloading 116/1013 (file index = 115)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_5_6.csv.gz
# Skipping...
# Downloading 117/1013 (file index = 116)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_5_7.csv.gz
# Skipping...
# Downloading 118/1013 (file index = 117)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_0_5.csv.gz
# Skipping...
# Downloading 119/1013 (file index = 118)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_6_0.csv.gz
# Skipping...
# Downloading 120/1013 (file index = 119)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_6_1.csv.gz
# Skipping...
# Downloading 121/1013 (file index = 120)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_6_2.csv.gz
# Skipping...
# Downloading 122/1013 (file index = 121)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_6_3.csv.gz
# Skipping...
# Downloading 123/1013 (file index = 122)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_6_4.csv.gz
# Skipping...
# Downloading 124/1013 (file index = 123)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_6_5.csv.gz
# Skipping...
# Downloading 125/1013 (file index = 124)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_6_6.csv.gz
# Skipping...
# Downloading 126/1013 (file index = 125)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_6_7.csv.gz
# Skipping...
# Downloading 127/1013 (file index = 126)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_0_6.csv.gz
# Skipping...
# Downloading 128/1013 (file index = 127)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_7_0.csv.gz
# Skipping...
# Downloading 129/1013 (file index = 128)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_7_1.csv.gz
# Skipping...
# Downloading 130/1013 (file index = 129)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_7_2.csv.gz
# Skipping...
# Downloading 131/1013 (file index = 130)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_7_3.csv.gz
# Skipping...
# Downloading 132/1013 (file index = 131)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_7_4.csv.gz
# Skipping...
# Downloading 133/1013 (file index = 132)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_7_5.csv.gz
# Skipping...
# Downloading 134/1013 (file index = 133)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_7_6.csv.gz
# Skipping...
# Downloading 135/1013 (file index = 134)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_10_7_7.csv.gz
# Skipping...
# Downloading 136/1013 (file index = 135)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_0_7.csv.gz
# Skipping...
# Downloading 137/1013 (file index = 136)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_0_0.csv.gz
# Skipping...
# Downloading 138/1013 (file index = 137)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_0_1.csv.gz
# Skipping...
# Downloading 139/1013 (file index = 138)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_0_2.csv.gz
# Skipping...
# Downloading 140/1013 (file index = 139)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_0_3.csv.gz
# Skipping...
# Downloading 141/1013 (file index = 140)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_0_4.csv.gz
# Skipping...
# Downloading 142/1013 (file index = 141)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_0_5.csv.gz
# Skipping...
# Downloading 143/1013 (file index = 142)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_0_6.csv.gz
# Skipping...
# Downloading 144/1013 (file index = 143)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_0_7.csv.gz
# Skipping...
# Downloading 145/1013 (file index = 144)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_1_0.csv.gz
# Skipping...
# Downloading 146/1013 (file index = 145)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_1_0.csv.gz
# Skipping...
# Downloading 147/1013 (file index = 146)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_1_1.csv.gz
# Skipping...
# Downloading 148/1013 (file index = 147)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_1_2.csv.gz
# Skipping...
# Downloading 149/1013 (file index = 148)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_1_3.csv.gz
# Skipping...
# Downloading 150/1013 (file index = 149)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_1_4.csv.gz
# Skipping...
# Downloading 151/1013 (file index = 150)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_1_5.csv.gz
# Skipping...
# Downloading 152/1013 (file index = 151)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_1_6.csv.gz
# Skipping...
# Downloading 153/1013 (file index = 152)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_1_1.csv.gz
# Skipping...
# Downloading 154/1013 (file index = 153)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_2_0.csv.gz
# Skipping...
# Downloading 155/1013 (file index = 154)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_2_1.csv.gz
# Skipping...
# Downloading 156/1013 (file index = 155)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_2_2.csv.gz
# Skipping...
# Downloading 157/1013 (file index = 156)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_2_3.csv.gz
# Skipping...
# Downloading 158/1013 (file index = 157)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_2_4.csv.gz
# Skipping...
# Downloading 159/1013 (file index = 158)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_2_5.csv.gz
# Skipping...
# Downloading 160/1013 (file index = 159)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_2_6.csv.gz
# Skipping...
# Downloading 161/1013 (file index = 160)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_2_7.csv.gz
# Skipping...
# Downloading 162/1013 (file index = 161)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_1_2.csv.gz
# Skipping...
# Downloading 163/1013 (file index = 162)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_3_0.csv.gz
# Skipping...
# Downloading 164/1013 (file index = 163)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_3_1.csv.gz
# Skipping...
# Downloading 165/1013 (file index = 164)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_3_2.csv.gz
# Skipping...
# Downloading 166/1013 (file index = 165)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_3_3.csv.gz
# Skipping...
# Downloading 167/1013 (file index = 166)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_3_4.csv.gz
# Skipping...
# Downloading 168/1013 (file index = 167)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_3_5.csv.gz
# Skipping...
# Downloading 169/1013 (file index = 168)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_1_3.csv.gz
# Skipping...
# Downloading 170/1013 (file index = 169)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_4_0.csv.gz
# Skipping...
# Downloading 171/1013 (file index = 170)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_4_1.csv.gz
# Skipping...
# Downloading 172/1013 (file index = 171)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_4_2.csv.gz
# Skipping...
# Downloading 173/1013 (file index = 172)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_4_3.csv.gz
# Skipping...
# Downloading 174/1013 (file index = 173)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_4_4.csv.gz
# Skipping...
# Downloading 175/1013 (file index = 174)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_4_5.csv.gz
# Skipping...
# Downloading 176/1013 (file index = 175)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_4_6.csv.gz
# Skipping...
# Downloading 177/1013 (file index = 176)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_4_7.csv.gz
# Skipping...
# Downloading 178/1013 (file index = 177)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_1_4.csv.gz
# Skipping...
# Downloading 179/1013 (file index = 178)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_5_0.csv.gz
# Skipping...
# Downloading 180/1013 (file index = 179)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_5_1.csv.gz
# Skipping...
# Downloading 181/1013 (file index = 180)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_5_2.csv.gz
# Skipping...
# Downloading 182/1013 (file index = 181)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_5_3.csv.gz
# Skipping...
# Downloading 183/1013 (file index = 182)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_5_4.csv.gz
# Skipping...
# Downloading 184/1013 (file index = 183)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_5_5.csv.gz
# Skipping...
# Downloading 185/1013 (file index = 184)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_5_6.csv.gz
# Skipping...
# Downloading 186/1013 (file index = 185)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_5_7.csv.gz
# Skipping...
# Downloading 187/1013 (file index = 186)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_1_5.csv.gz
# Skipping...
# Downloading 188/1013 (file index = 187)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_6_0.csv.gz
# Skipping...
# Downloading 189/1013 (file index = 188)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_6_1.csv.gz
# Skipping...
# Downloading 190/1013 (file index = 189)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_6_2.csv.gz
# Skipping...
# Downloading 191/1013 (file index = 190)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_6_3.csv.gz
# Skipping...
# Downloading 192/1013 (file index = 191)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_6_4.csv.gz
# Skipping...
# Downloading 193/1013 (file index = 192)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_6_5.csv.gz
# Skipping...
# Downloading 194/1013 (file index = 193)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_6_6.csv.gz
# Skipping...
# Downloading 195/1013 (file index = 194)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_6_7.csv.gz
# Skipping...
# Downloading 196/1013 (file index = 195)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_1_6.csv.gz
# Skipping...
# Downloading 197/1013 (file index = 196)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_7_0.csv.gz
# Skipping...
# Downloading 198/1013 (file index = 197)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_7_1.csv.gz
# Skipping...
# Downloading 199/1013 (file index = 198)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_7_2.csv.gz
# Skipping...
# Downloading 200/1013 (file index = 199)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_7_3.csv.gz
# Skipping...
# Downloading 201/1013 (file index = 200)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_7_4.csv.gz
# Skipping...
# Downloading 202/1013 (file index = 201)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_7_5.csv.gz
# Skipping...
# Downloading 203/1013 (file index = 202)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_7_6.csv.gz
# Skipping...
# Downloading 204/1013 (file index = 203)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_11_7_7.csv.gz
# Skipping...
# Downloading 205/1013 (file index = 204)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_1_7.csv.gz
# Skipping...
# Downloading 206/1013 (file index = 205)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_0_0.csv.gz
# Skipping...
# Downloading 207/1013 (file index = 206)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_0_1.csv.gz
# Skipping...
# Downloading 208/1013 (file index = 207)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_0_2.csv.gz
# Skipping...
# Downloading 209/1013 (file index = 208)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_0_3.csv.gz
# Skipping...
# Downloading 210/1013 (file index = 209)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_0_4.csv.gz
# Skipping...
# Downloading 211/1013 (file index = 210)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_0_5.csv.gz
# Skipping...
# Downloading 212/1013 (file index = 211)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_0_6.csv.gz
# Skipping...
# Downloading 213/1013 (file index = 212)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_0_7.csv.gz
# Skipping...
# Downloading 214/1013 (file index = 213)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_2_0.csv.gz
# Skipping...
# Downloading 215/1013 (file index = 214)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_1_0.csv.gz
# Skipping...
# Downloading 216/1013 (file index = 215)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_1_1.csv.gz
# Skipping...
# Downloading 217/1013 (file index = 216)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_1_2.csv.gz
# Skipping...
# Downloading 218/1013 (file index = 217)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_1_3.csv.gz
# Skipping...
# Downloading 219/1013 (file index = 218)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_1_4.csv.gz
# Skipping...
# Downloading 220/1013 (file index = 219)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_1_5.csv.gz
# Skipping...
# Downloading 221/1013 (file index = 220)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_1_6.csv.gz
# Skipping...
# Downloading 222/1013 (file index = 221)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_1_7.csv.gz
# Skipping...
# Downloading 223/1013 (file index = 222)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_2_1.csv.gz
# Skipping...
# Downloading 224/1013 (file index = 223)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_2_0.csv.gz
# Skipping...
# Downloading 225/1013 (file index = 224)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_2_1.csv.gz
# Skipping...
# Downloading 226/1013 (file index = 225)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_2_2.csv.gz
# Skipping...
# Downloading 227/1013 (file index = 226)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_2_3.csv.gz
# Skipping...
# Downloading 228/1013 (file index = 227)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_2_4.csv.gz
# Skipping...
# Downloading 229/1013 (file index = 228)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_2_5.csv.gz
# Skipping...
# Downloading 230/1013 (file index = 229)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_2_6.csv.gz
# Skipping...
# Downloading 231/1013 (file index = 230)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_2_7.csv.gz
# Skipping...
# Downloading 232/1013 (file index = 231)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_2_2.csv.gz
# Skipping...
# Downloading 233/1013 (file index = 232)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_3_0.csv.gz
# Skipping...
# Downloading 234/1013 (file index = 233)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_3_1.csv.gz
# Skipping...
# Downloading 235/1013 (file index = 234)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_3_2.csv.gz
# Skipping...
# Downloading 236/1013 (file index = 235)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_3_3.csv.gz
# Skipping...
# Downloading 237/1013 (file index = 236)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_3_4.csv.gz
# Skipping...
# Downloading 238/1013 (file index = 237)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_3_5.csv.gz
# Skipping...
# Downloading 239/1013 (file index = 238)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_3_6.csv.gz
# Skipping...
# Downloading 240/1013 (file index = 239)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_3_7.csv.gz
# Skipping...
# Downloading 241/1013 (file index = 240)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_2_3.csv.gz
# Skipping...
# Downloading 242/1013 (file index = 241)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_4_0.csv.gz
# Skipping...
# Downloading 243/1013 (file index = 242)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_4_1.csv.gz
# Skipping...
# Downloading 244/1013 (file index = 243)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_4_2.csv.gz
# Skipping...
# Downloading 245/1013 (file index = 244)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_4_3.csv.gz
# Skipping...
# Downloading 246/1013 (file index = 245)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_4_4.csv.gz
# Skipping...
# Downloading 247/1013 (file index = 246)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_4_5.csv.gz
# Skipping...
# Downloading 248/1013 (file index = 247)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_4_6.csv.gz
# Skipping...
# Downloading 249/1013 (file index = 248)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_4_7.csv.gz
# Skipping...
# Downloading 250/1013 (file index = 249)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_2_4.csv.gz
# Skipping...
# Downloading 251/1013 (file index = 250)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_5_0.csv.gz
# Skipping...
# Downloading 252/1013 (file index = 251)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_5_1.csv.gz
# Skipping...
# Downloading 253/1013 (file index = 252)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_5_2.csv.gz
# Skipping...
# Downloading 254/1013 (file index = 253)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_5_3.csv.gz
# Skipping...
# Downloading 255/1013 (file index = 254)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_5_4.csv.gz
# Skipping...
# Downloading 256/1013 (file index = 255)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_5_5.csv.gz
# Skipping...
# Downloading 257/1013 (file index = 256)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_5_6.csv.gz
# Skipping...
# Downloading 258/1013 (file index = 257)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_5_7.csv.gz
# Skipping...
# Downloading 259/1013 (file index = 258)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_2_5.csv.gz
# Skipping...
# Downloading 260/1013 (file index = 259)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_6_0.csv.gz
# Skipping...
# Downloading 261/1013 (file index = 260)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_6_1.csv.gz
# Skipping...
# Downloading 262/1013 (file index = 261)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_6_2.csv.gz
# Skipping...
# Downloading 263/1013 (file index = 262)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_6_3.csv.gz
# Skipping...
# Downloading 264/1013 (file index = 263)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_6_4.csv.gz
# Skipping...
# Downloading 265/1013 (file index = 264)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_6_5.csv.gz
# Skipping...
# Downloading 266/1013 (file index = 265)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_6_6.csv.gz
# Skipping...
# Downloading 267/1013 (file index = 266)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_6_7.csv.gz
# Skipping...
# Downloading 268/1013 (file index = 267)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_2_6.csv.gz
# Skipping...
# Downloading 269/1013 (file index = 268)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_7_0.csv.gz
# Skipping...
# Downloading 270/1013 (file index = 269)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_7_1.csv.gz
# Skipping...
# Downloading 271/1013 (file index = 270)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_7_2.csv.gz
# Skipping...
# Downloading 272/1013 (file index = 271)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_7_3.csv.gz
# Skipping...
# Downloading 273/1013 (file index = 272)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_7_4.csv.gz
# Skipping...
# Downloading 274/1013 (file index = 273)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_7_5.csv.gz
# Skipping...
# Downloading 275/1013 (file index = 274)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_7_6.csv.gz
# Skipping...
# Downloading 276/1013 (file index = 275)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_12_7_7.csv.gz
# Skipping...
# Downloading 277/1013 (file index = 276)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_2_7.csv.gz
# Skipping...
# Downloading 278/1013 (file index = 277)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_0_0.csv.gz
# Skipping...
# Downloading 279/1013 (file index = 278)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_0_1.csv.gz
# Skipping...
# Downloading 280/1013 (file index = 279)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_0_2.csv.gz
# Skipping...
# Downloading 281/1013 (file index = 280)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_0_3.csv.gz
# Skipping...
# Downloading 282/1013 (file index = 281)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_0_4.csv.gz
# Skipping...
# Downloading 283/1013 (file index = 282)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_0_5.csv.gz
# Skipping...
# Downloading 284/1013 (file index = 283)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_0_6.csv.gz
# Skipping...
# Downloading 285/1013 (file index = 284)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_0_7.csv.gz
# Skipping...
# Downloading 286/1013 (file index = 285)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_3_0.csv.gz
# Skipping...
# Downloading 287/1013 (file index = 286)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_1_0.csv.gz
# Skipping...
# Downloading 288/1013 (file index = 287)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_1_1.csv.gz
# Skipping...
# Downloading 289/1013 (file index = 288)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_1_2.csv.gz
# Skipping...
# Downloading 290/1013 (file index = 289)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_1_3.csv.gz
# Skipping...
# Downloading 291/1013 (file index = 290)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_1_4.csv.gz
# Skipping...
# Downloading 292/1013 (file index = 291)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_1_5.csv.gz
# Skipping...
# Downloading 293/1013 (file index = 292)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_1_6.csv.gz
# Skipping...
# Downloading 294/1013 (file index = 293)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_1_7.csv.gz
# Skipping...
# Downloading 295/1013 (file index = 294)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_3_1.csv.gz
# Skipping...
# Downloading 296/1013 (file index = 295)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_2_0.csv.gz
# Skipping...
# Downloading 297/1013 (file index = 296)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_2_1.csv.gz
# Skipping...
# Downloading 298/1013 (file index = 297)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_2_2.csv.gz
# Skipping...
# Downloading 299/1013 (file index = 298)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_2_3.csv.gz
# Skipping...
# Downloading 300/1013 (file index = 299)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_2_4.csv.gz
# Skipping...
# Downloading 301/1013 (file index = 300)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_2_5.csv.gz
# Skipping...
# Downloading 302/1013 (file index = 301)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_2_6.csv.gz
# Skipping...
# Downloading 303/1013 (file index = 302)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_2_7.csv.gz
# Skipping...
# Downloading 304/1013 (file index = 303)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_3_2.csv.gz
# Skipping...
# Downloading 305/1013 (file index = 304)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_3_0.csv.gz
# Skipping...
# Downloading 306/1013 (file index = 305)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_3_1.csv.gz
# Skipping...
# Downloading 307/1013 (file index = 306)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_3_2.csv.gz
# Skipping...
# Downloading 308/1013 (file index = 307)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_3_3.csv.gz
# Skipping...
# Downloading 309/1013 (file index = 308)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_3_4.csv.gz
# Skipping...
# Downloading 310/1013 (file index = 309)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_3_5.csv.gz
# Skipping...
# Downloading 311/1013 (file index = 310)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_3_6.csv.gz
# Skipping...
# Downloading 312/1013 (file index = 311)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_3_7.csv.gz
# Skipping...
# Downloading 313/1013 (file index = 312)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_3_3.csv.gz
# Skipping...
# Downloading 314/1013 (file index = 313)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_4_0.csv.gz
# Skipping...
# Downloading 315/1013 (file index = 314)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_4_1.csv.gz
# Skipping...
# Downloading 316/1013 (file index = 315)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_4_2.csv.gz
# Skipping...
# Downloading 317/1013 (file index = 316)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_4_3.csv.gz
# Skipping...
# Downloading 318/1013 (file index = 317)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_4_4.csv.gz
# Skipping...
# Downloading 319/1013 (file index = 318)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_4_5.csv.gz
# Skipping...
# Downloading 320/1013 (file index = 319)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_4_6.csv.gz
# Skipping...
# Downloading 321/1013 (file index = 320)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_4_7.csv.gz
# Skipping...
# Downloading 322/1013 (file index = 321)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_3_4.csv.gz
# Skipping...
# Downloading 323/1013 (file index = 322)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_5_0.csv.gz
# Skipping...
# Downloading 324/1013 (file index = 323)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_5_1.csv.gz
# Skipping...
# Downloading 325/1013 (file index = 324)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_5_2.csv.gz
# Skipping...
# Downloading 326/1013 (file index = 325)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_5_3.csv.gz
# Skipping...
# Downloading 327/1013 (file index = 326)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_5_4.csv.gz
# Skipping...
# Downloading 328/1013 (file index = 327)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_5_5.csv.gz
# Skipping...
# Downloading 329/1013 (file index = 328)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_5_6.csv.gz
# Skipping...
# Downloading 330/1013 (file index = 329)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_5_7.csv.gz
# Skipping...
# Downloading 331/1013 (file index = 330)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_3_5.csv.gz
# Skipping...
# Downloading 332/1013 (file index = 331)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_6_0.csv.gz
# Skipping...
# Downloading 333/1013 (file index = 332)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_6_1.csv.gz
# Skipping...
# Downloading 334/1013 (file index = 333)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_6_2.csv.gz
# Skipping...
# Downloading 335/1013 (file index = 334)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_6_3.csv.gz
# Skipping...
# Downloading 336/1013 (file index = 335)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_6_4.csv.gz
# Skipping...
# Downloading 337/1013 (file index = 336)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_6_5.csv.gz
# Skipping...
# Downloading 338/1013 (file index = 337)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_6_6.csv.gz
# Skipping...
# Downloading 339/1013 (file index = 338)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_6_7.csv.gz
# Skipping...
# Downloading 340/1013 (file index = 339)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_3_6.csv.gz
# Skipping...
# Downloading 341/1013 (file index = 340)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_7_0.csv.gz
# Skipping...
# Downloading 342/1013 (file index = 341)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_7_1.csv.gz
# Skipping...
# Downloading 343/1013 (file index = 342)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_7_2.csv.gz
# Skipping...
# Downloading 344/1013 (file index = 343)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_7_3.csv.gz
# Skipping...
# Downloading 345/1013 (file index = 344)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_7_4.csv.gz
# Skipping...
# Downloading 346/1013 (file index = 345)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_7_5.csv.gz
# Skipping...
# Downloading 347/1013 (file index = 346)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_7_6.csv.gz
# Skipping...
# Downloading 348/1013 (file index = 347)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_13_7_7.csv.gz
# Skipping...
# Downloading 349/1013 (file index = 348)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_3_7.csv.gz
# Skipping...
# Downloading 350/1013 (file index = 349)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_1_3_8.csv.gz
# Skipping...
# Downloading 351/1013 (file index = 350)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_14_0_0.csv.gz
# Skipping...
# Downloading 352/1013 (file index = 351)
# File already exists: H:/data/DEWEY/Veraset/Home Location/home-location_14_0_1.csv.gz
# Skipping...
# Downloading 353/1013 (file index = 352)
# ...
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_2_7.csv.gz
# Please be patient. It may take a while...
#
# Downloading 913/1013 (file index = 912)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_3_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 914/1013 (file index = 913)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_3_1.csv.gz
# Please be patient. It may take a while...
#
# Downloading 915/1013 (file index = 914)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_3_2.csv.gz
# Please be patient. It may take a while...
#
# Downloading 916/1013 (file index = 915)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_3_3.csv.gz
# Please be patient. It may take a while...
#
# Downloading 917/1013 (file index = 916)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_3_4.csv.gz
# Please be patient. It may take a while...
#
# Downloading 918/1013 (file index = 917)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_3_5.csv.gz
# Please be patient. It may take a while...
#
# Downloading 919/1013 (file index = 918)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_3_6.csv.gz
# Please be patient. It may take a while...
#
# Downloading 920/1013 (file index = 919)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_3_7.csv.gz
# Please be patient. It may take a while...
#
# Downloading 921/1013 (file index = 920)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_4_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 922/1013 (file index = 921)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_4_1.csv.gz
# Please be patient. It may take a while...
#
# Downloading 923/1013 (file index = 922)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_4_2.csv.gz
# Please be patient. It may take a while...
#
# Downloading 924/1013 (file index = 923)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_4_3.csv.gz
# Please be patient. It may take a while...
#
# Downloading 925/1013 (file index = 924)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_4_4.csv.gz
# Please be patient. It may take a while...
#
# Downloading 926/1013 (file index = 925)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_5_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 927/1013 (file index = 926)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_5_1.csv.gz
# Please be patient. It may take a while...
#
# Downloading 928/1013 (file index = 927)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_5_2.csv.gz
# Please be patient. It may take a while...
#
# Downloading 929/1013 (file index = 928)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_5_3.csv.gz
# Please be patient. It may take a while...
#
# Downloading 930/1013 (file index = 929)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_5_4.csv.gz
# Please be patient. It may take a while...
#
# Downloading 931/1013 (file index = 930)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_5_5.csv.gz
# Please be patient. It may take a while...
#
# Downloading 932/1013 (file index = 931)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_5_6.csv.gz
# Please be patient. It may take a while...
#
# Downloading 933/1013 (file index = 932)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_5_7.csv.gz
# Please be patient. It may take a while...
#
# Downloading 934/1013 (file index = 933)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_6_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 935/1013 (file index = 934)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_6_1.csv.gz
# Please be patient. It may take a while...
#
# Downloading 936/1013 (file index = 935)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_6_2.csv.gz
# Please be patient. It may take a while...
#
# Downloading 937/1013 (file index = 936)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_6_3.csv.gz
# Please be patient. It may take a while...
#
# Downloading 938/1013 (file index = 937)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_6_4.csv.gz
# Please be patient. It may take a while...
#
# Downloading 939/1013 (file index = 938)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_6_5.csv.gz
# Please be patient. It may take a while...
#
# Downloading 940/1013 (file index = 939)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_6_6.csv.gz
# Please be patient. It may take a while...
#
# Downloading 941/1013 (file index = 940)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_6_7.csv.gz
# Please be patient. It may take a while...
#
# Downloading 942/1013 (file index = 941)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_7_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 943/1013 (file index = 942)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_7_1.csv.gz
# Please be patient. It may take a while...
#
# Downloading 944/1013 (file index = 943)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_7_2.csv.gz
# Please be patient. It may take a while...
#
# Downloading 945/1013 (file index = 944)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_7_3.csv.gz
# Please be patient. It may take a while...
#
# Downloading 946/1013 (file index = 945)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_7_4.csv.gz
# Please be patient. It may take a while...
#
# Downloading 947/1013 (file index = 946)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_7_5.csv.gz
# Please be patient. It may take a while...
#
# Downloading 948/1013 (file index = 947)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_7_6.csv.gz
# Please be patient. It may take a while...
#
# Downloading 949/1013 (file index = 948)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_8_7_7.csv.gz
# Please be patient. It may take a while...
#
# Downloading 950/1013 (file index = 949)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_0_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 951/1013 (file index = 950)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_0_1.csv.gz
# Please be patient. It may take a while...
#
# Downloading 952/1013 (file index = 951)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_0_2.csv.gz
# Please be patient. It may take a while...
#
# Downloading 953/1013 (file index = 952)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_0_3.csv.gz
# Please be patient. It may take a while...
#
# Downloading 954/1013 (file index = 953)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_0_4.csv.gz
# Please be patient. It may take a while...
#
# Downloading 955/1013 (file index = 954)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_0_5.csv.gz
# Please be patient. It may take a while...
#
# Downloading 956/1013 (file index = 955)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_0_6.csv.gz
# Please be patient. It may take a while...
#
# Downloading 957/1013 (file index = 956)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_0_7.csv.gz
# Please be patient. It may take a while...
#
# Downloading 958/1013 (file index = 957)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_1_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 959/1013 (file index = 958)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_1_1.csv.gz
# Please be patient. It may take a while...
#
# Downloading 960/1013 (file index = 959)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_1_2.csv.gz
# Please be patient. It may take a while...
#
# Downloading 961/1013 (file index = 960)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_1_3.csv.gz
# Please be patient. It may take a while...
#
# Downloading 962/1013 (file index = 961)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_1_4.csv.gz
# Please be patient. It may take a while...
#
# Downloading 963/1013 (file index = 962)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_1_5.csv.gz
# Please be patient. It may take a while...
#
# Downloading 964/1013 (file index = 963)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_1_6.csv.gz
# Please be patient. It may take a while...
#
# Downloading 965/1013 (file index = 964)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_1_7.csv.gz
# Please be patient. It may take a while...
#
# Downloading 966/1013 (file index = 965)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_2_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 967/1013 (file index = 966)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_2_1.csv.gz
# Please be patient. It may take a while...
#
# Downloading 968/1013 (file index = 967)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_2_2.csv.gz
# Please be patient. It may take a while...
#
# Downloading 969/1013 (file index = 968)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_2_3.csv.gz
# Please be patient. It may take a while...
#
# Downloading 970/1013 (file index = 969)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_2_4.csv.gz
# Please be patient. It may take a while...
#
# Downloading 971/1013 (file index = 970)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_2_5.csv.gz
# Please be patient. It may take a while...
#
# Downloading 972/1013 (file index = 971)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_2_6.csv.gz
# Please be patient. It may take a while...
#
# Downloading 973/1013 (file index = 972)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_2_7.csv.gz
# Please be patient. It may take a while...
#
# Downloading 974/1013 (file index = 973)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_3_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 975/1013 (file index = 974)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_3_1.csv.gz
# Please be patient. It may take a while...
#
# Downloading 976/1013 (file index = 975)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_3_2.csv.gz
# Please be patient. It may take a while...
#
# Downloading 977/1013 (file index = 976)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_3_3.csv.gz
# Please be patient. It may take a while...
#
# Downloading 978/1013 (file index = 977)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_3_4.csv.gz
# Please be patient. It may take a while...
#
# Downloading 979/1013 (file index = 978)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_3_5.csv.gz
# Please be patient. It may take a while...
#
# Downloading 980/1013 (file index = 979)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_3_6.csv.gz
# Please be patient. It may take a while...
#
# Downloading 981/1013 (file index = 980)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_3_7.csv.gz
# Please be patient. It may take a while...
#
# Downloading 982/1013 (file index = 981)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_4_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 983/1013 (file index = 982)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_4_1.csv.gz
# Please be patient. It may take a while...
#
# Downloading 984/1013 (file index = 983)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_4_2.csv.gz
# Please be patient. It may take a while...
#
# Downloading 985/1013 (file index = 984)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_4_3.csv.gz
# Please be patient. It may take a while...
#
# Downloading 986/1013 (file index = 985)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_4_4.csv.gz
# Please be patient. It may take a while...
#
# Downloading 987/1013 (file index = 986)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_4_5.csv.gz
# Please be patient. It may take a while...
#
# Downloading 988/1013 (file index = 987)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_4_6.csv.gz
# Please be patient. It may take a while...
#
# Downloading 989/1013 (file index = 988)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_4_7.csv.gz
# Please be patient. It may take a while...
#
# Downloading 990/1013 (file index = 989)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_5_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 991/1013 (file index = 990)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_5_1.csv.gz
# Please be patient. It may take a while...
#
# Downloading 992/1013 (file index = 991)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_5_2.csv.gz
# Please be patient. It may take a while...
#
# Downloading 993/1013 (file index = 992)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_5_3.csv.gz
# Please be patient. It may take a while...
#
# Downloading 994/1013 (file index = 993)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_5_4.csv.gz
# Please be patient. It may take a while...
#
# Downloading 995/1013 (file index = 994)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_5_5.csv.gz
# Please be patient. It may take a while...
#
# Downloading 996/1013 (file index = 995)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_5_6.csv.gz
# Please be patient. It may take a while...
#
# Downloading 997/1013 (file index = 996)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_5_7.csv.gz
# Please be patient. It may take a while...
#
# Downloading 998/1013 (file index = 997)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_6_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 999/1013 (file index = 998)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_6_1.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1000/1013 (file index = 999)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_6_2.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1001/1013 (file index = 1000)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_6_3.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1002/1013 (file index = 1001)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_6_4.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1003/1013 (file index = 1002)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_6_5.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1004/1013 (file index = 1003)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_6_6.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1005/1013 (file index = 1004)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_6_7.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1006/1013 (file index = 1005)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_7_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1007/1013 (file index = 1006)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_7_1.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1008/1013 (file index = 1007)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_7_2.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1009/1013 (file index = 1008)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_7_3.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1010/1013 (file index = 1009)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_7_4.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1011/1013 (file index = 1010)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_7_5.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1012/1013 (file index = 1011)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_7_6.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1013/1013 (file index = 1012)
# Writing H:/data/DEWEY/Veraset/Home Location/home-location_9_7_7.csv.gz
# Please be patient. It may take a while...
