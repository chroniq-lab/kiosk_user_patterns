# %%
import sys
import os
from pathlib import Path
import pyarrow.parquet as pq
import pyarrow.dataset as ds
import pandas as pd
import matplotlib.pyplot as plt
sys.path.append(str(Path.cwd().parent))
from config import PATH_KIOSK_USER_PATTERNS_FOLDER, PATH_KIOSK_USER_PATTERNS_REPO, PATH_DATA_SHARING_FOLDER, PATH_C_DEWEY_FOLDER

# Example usage
kupdat04_path = PATH_C_DEWEY_FOLDER /'DEWEY'
execfile(PATH_KIOSK_USER_PATTERNS_REPO / 'constants.py')

# %%
data_endpoint = 'https://app.deweydata.io/api/v1/external/data/fldr_jfmsd3bmxjp4z8aff'
import numpy as np
import deweydatapy as ddp
execfile(PATH_KIOSK_USER_PATTERNS_REPO / 'functions/extract_file_list.py')

# %%
files, meta = extract_file_list(bulk_api_pass_by_retail_store_visits, data_endpoint)
files.to_csv(PATH_KIOSK_USER_PATTERNS_REPO / 'data' / f'kupdat09b_pass_by retail store visits.csv')
files = pd.read_csv(PATH_KIOSK_USER_PATTERNS_REPO / 'data' / f'kupdat09b_pass_by retail store visits.csv')
files.head()
# Out:
#
# Metadata summary ------------------------------------------------
# Total number of files: 170
# Total files size (MB): 61,365.41
# Date aggregation: MONTH
# Date partition column: WEEK_STARTING
# Data min available date: 2018-12
# Data max available date: 2024-12
# -----------------------------------------------------------------
#
# Collecting files information for page 1/4...
# Collecting files information for page 2/4...
# Collecting files information for page 3/4...
# Collecting files information for page 4/4...
# Files information collection completed.
#
# Files information summary ---------------------------------------
# Total number of pages: 4
# Total number of files: 154
# Total files size (MB): 55,837.87
# Average single file size (MB): 370.99
# Date partition column: WEEK_STARTING
# Expires at: 2025-07-18T15:41:26.548468+00:00
# -----------------------------------------------------------------
#    Unnamed: 0  index  page                                               link  \
# 0           0      0     1  https://app.deweydata.io/api/v1/downloads/0198...
# 1           1      1     1  https://app.deweydata.io/api/v1/downloads/0198...
# 2           2      2     1  https://app.deweydata.io/api/v1/downloads/0198...
# 3           3      3     1  https://app.deweydata.io/api/v1/downloads/0198...
# 4           4      4     1  https://app.deweydata.io/api/v1/downloads/0198...
#
#   partition_key                                          file_name  \
# 0       2019-01  data_01bca733-0205-6d70-0042-fa0702a16be6_1604...
# 1       2019-01  data_01bca733-0205-6d70-0042-fa0702a16be6_1604...
# 2       2019-02  data_01bca733-0205-6d70-0042-fa0702a16be6_904_...
# 3       2019-02  data_01bca733-0205-6d70-0042-fa0702a16be6_904_...
# 4       2019-03  data_01bca733-0205-6d70-0042-fa0702a16be6_1004...
#
#   file_extension  file_size_bytes                       modified_at  \
# 0        .csv.gz        419440114  2025-05-28T15:49:12.271000+00:00
# 1        .csv.gz        373725494  2025-05-28T15:51:52.474000+00:00
# 2        .csv.gz        419460411  2025-05-28T15:49:13.584000+00:00
# 3        .csv.gz        384443572  2025-05-28T15:51:52.473000+00:00
# 4        .csv.gz        419467026  2025-05-28T15:48:57.667000+00:00
#
#                                  external_id  \
# 0  dwll_0198190c-3296-7ed1-b926-457e14953fd5
# 1  dwll_0198190c-3296-7ed1-b926-458930dd9abb
# 2  dwll_0198190c-3296-7ed1-b926-459186f2b897
# 3  dwll_0198190c-3296-7ed1-b926-45acddcab36a
# 4  dwll_0198190c-3296-7ed1-b926-45baadca5c84
#
#                                        download_link
# 0  https://app.deweydata.io/api/v1/downloads/0198...
# 1  https://app.deweydata.io/api/v1/downloads/0198...
# 2  https://app.deweydata.io/api/v1/downloads/0198...
# 3  https://app.deweydata.io/api/v1/downloads/0198...
# 4  https://app.deweydata.io/api/v1/downloads/0198...

# %%
error_dict = {}

for y in range(2024, 2017, -1):
    dest_dir = fr'R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/{y}/'
    os.makedirs(dest_dir, exist_ok=True)
    execfile(PATH_KIOSK_USER_PATTERNS_REPO / 'constants.py')
    for m in range(12,0,-1):

        key = f'{y}-{m:02d}'
        print(key)
            # Ensure 'partition_key' in files and 'date' in sampled are both datetime type
        split = files[files['partition_key'] == key]

        error_list = []
        for idx, row in split.iterrows():
            try:
                ddp.download_files(pd.DataFrame([row]), dest_folder=dest_dir, skip_exists=True)
            except Exception as e:
                error_list.append(idx)
                print(f"Download failed for index {idx}: {e}")
        error_dict[key] = pd.Series(error_list, dtype='object')
# Out:
# 2024-12
# 2024-11
# Downloading 1/1 (file index = 152)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_1804_2_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 153)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_1804_2_1.csv.gz
# Skipping...
# 2024-10
# Downloading 1/1 (file index = 150)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_704_5_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 151)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_704_5_1.csv.gz
# Skipping...
# 2024-09
# Downloading 1/1 (file index = 147)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_204_4_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 148)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_204_4_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 149)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_204_4_2.csv.gz
# Skipping...
# 2024-08
# Downloading 1/1 (file index = 145)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_204_6_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 146)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_204_6_1.csv.gz
# Skipping...
# 2024-07
# Downloading 1/1 (file index = 143)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_3004_0_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 144)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_3004_0_1.csv.gz
# Skipping...
# 2024-06
# Downloading 1/1 (file index = 140)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_1504_2_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 141)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_1504_2_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 142)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_1504_2_2.csv.gz
# Skipping...
# 2024-05
# Downloading 1/1 (file index = 138)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_1004_5_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 139)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_1004_5_1.csv.gz
# Skipping...
# 2024-04
# Downloading 1/1 (file index = 136)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_2604_1_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 137)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_2604_1_1.csv.gz
# Skipping...
# 2024-03
# Downloading 1/1 (file index = 133)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_2104_1_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 134)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_2104_1_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 135)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_2104_1_2.csv.gz
# Skipping...
# 2024-02
# Downloading 1/1 (file index = 131)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_1104_1_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 132)
# Writing R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_1104_1_1.csv.gz
# Please be patient. It may take a while...
#
# 2024-01
# Downloading 1/1 (file index = 129)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_504_0_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 130)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024/data_01bca733-0205-6d70-0042-fa0702a16be6_504_0_1.csv.gz
# Skipping...
# 2023-12
# 2023-11
# Downloading 1/1 (file index = 127)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_2504_7_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 128)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_2504_7_1.csv.gz
# Skipping...
# 2023-10
# Downloading 1/1 (file index = 124)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_2104_3_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 125)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_2104_3_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 126)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_2104_3_2.csv.gz
# Skipping...
# 2023-09
# Downloading 1/1 (file index = 122)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_504_6_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 123)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_504_6_1.csv.gz
# Skipping...
# 2023-08
# Downloading 1/1 (file index = 120)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_304_1_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 121)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_304_1_1.csv.gz
# Skipping...
# 2023-07
# Downloading 1/1 (file index = 117)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_2004_7_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 118)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_2004_7_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 119)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_2004_7_2.csv.gz
# Skipping...
# 2023-06
# Downloading 1/1 (file index = 115)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_2504_3_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 116)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_2504_3_1.csv.gz
# Skipping...
# 2023-05
# Downloading 1/1 (file index = 113)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_1504_2_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 114)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_1504_2_1.csv.gz
# Skipping...
# 2023-04
# Downloading 1/1 (file index = 110)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_2904_2_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 111)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_2904_2_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 112)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_2904_2_2.csv.gz
# Skipping...
# 2023-03
# Downloading 1/1 (file index = 108)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_604_3_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 109)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_604_3_1.csv.gz
# Skipping...
# 2023-02
# Downloading 1/1 (file index = 106)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_1204_1_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 107)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_1204_1_1.csv.gz
# Skipping...
# 2023-01
# Downloading 1/1 (file index = 103)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_604_7_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 104)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_604_7_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 105)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2023/data_01bca733-0205-6d70-0042-fa0702a16be6_604_7_2.csv.gz
# Skipping...
# 2022-12
# 2022-11
# Downloading 1/1 (file index = 101)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1304_0_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 102)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1304_0_1.csv.gz
# Skipping...
# 2022-10
# Downloading 1/1 (file index = 98)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_2304_2_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 99)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_2304_2_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 100)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_2304_2_2.csv.gz
# Skipping...
# 2022-09
# Downloading 1/1 (file index = 96)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_2604_5_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 97)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_2604_5_1.csv.gz
# Skipping...
# 2022-08
# Downloading 1/1 (file index = 94)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1804_2_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 95)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1804_2_1.csv.gz
# Skipping...
# 2022-07
# Downloading 1/1 (file index = 91)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1504_5_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 92)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1504_5_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 93)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1504_5_2.csv.gz
# Skipping...
# 2022-06
# Downloading 1/1 (file index = 89)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1104_1_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 90)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1104_1_1.csv.gz
# Skipping...
# 2022-05
# Downloading 1/1 (file index = 86)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1304_1_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 87)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1304_1_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 88)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1304_1_2.csv.gz
# Skipping...
# 2022-04
# Downloading 1/1 (file index = 84)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_404_4_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 85)
# Writing R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_404_4_1.csv.gz
# Please be patient. It may take a while...
#
# 2022-03
# Downloading 1/1 (file index = 82)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_3004_2_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 83)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_3004_2_1.csv.gz
# Skipping...
# 2022-02
# Downloading 1/1 (file index = 80)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1704_2_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 81)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1704_2_1.csv.gz
# Skipping...
# 2022-01
# Downloading 1/1 (file index = 77)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1004_1_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 78)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1004_1_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 79)
# Writing R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022/data_01bca733-0205-6d70-0042-fa0702a16be6_1004_1_2.csv.gz
# Please be patient. It may take a while...
#
# 2021-12
# 2021-11
# Downloading 1/1 (file index = 75)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_1304_5_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 76)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_1304_5_1.csv.gz
# Skipping...
# 2021-10
# Downloading 1/1 (file index = 72)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_904_1_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 73)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_904_1_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 74)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_904_1_2.csv.gz
# Skipping...
# 2021-09
# Downloading 1/1 (file index = 70)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_3004_4_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 71)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_3004_4_1.csv.gz
# Skipping...
# 2021-08
# Downloading 1/1 (file index = 67)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_2304_5_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 68)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_2304_5_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 69)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_2304_5_2.csv.gz
# Skipping...
# 2021-07
# Downloading 1/1 (file index = 65)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_1704_5_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 66)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_1704_5_1.csv.gz
# Skipping...
# 2021-06
# Downloading 1/1 (file index = 63)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_204_1_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 64)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_204_1_1.csv.gz
# Skipping...
# 2021-05
# Downloading 1/1 (file index = 60)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_1204_3_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 61)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_1204_3_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 62)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_1204_3_2.csv.gz
# Skipping...
# 2021-04
# Downloading 1/1 (file index = 58)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_204_6_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 59)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_204_6_1.csv.gz
# Skipping...
# 2021-03
# Downloading 1/1 (file index = 56)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_1904_4_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 57)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_1904_4_1.csv.gz
# Skipping...
# 2021-02
# Downloading 1/1 (file index = 54)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_1604_5_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 55)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_1604_5_1.csv.gz
# Skipping...
# 2021-01
# Downloading 1/1 (file index = 51)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_404_4_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 52)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_404_4_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 53)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2021/data_01bca733-0205-6d70-0042-fa0702a16be6_404_4_2.csv.gz
# Skipping...
# 2020-12
# 2020-11
# Downloading 1/1 (file index = 48)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_1204_2_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 49)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_1204_2_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 50)
# Writing R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_1204_2_2.csv.gz
# Please be patient. It may take a while...
#
# 2020-10
# Downloading 1/1 (file index = 46)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_504_7_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 47)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_504_7_1.csv.gz
# Skipping...
# 2020-09
# Downloading 1/1 (file index = 44)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_2704_6_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 45)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_2704_6_1.csv.gz
# Skipping...
# 2020-08
# Downloading 1/1 (file index = 41)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_1504_3_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 42)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_1504_3_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 43)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_1504_3_2.csv.gz
# Skipping...
# 2020-07
# Downloading 1/1 (file index = 39)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_904_3_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 40)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_904_3_1.csv.gz
# Skipping...
# 2020-06
# Downloading 1/1 (file index = 37)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_1804_2_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 38)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_1804_2_1.csv.gz
# Skipping...
# 2020-05
# Downloading 1/1 (file index = 34)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_2904_0_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 35)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_2904_0_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 36)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_2904_0_2.csv.gz
# Skipping...
# 2020-04
# Downloading 1/1 (file index = 32)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_1304_2_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 33)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_1304_2_1.csv.gz
# Skipping...
# 2020-03
# Downloading 1/1 (file index = 30)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_1404_6_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 31)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_1404_6_1.csv.gz
# Skipping...
# 2020-02
# Downloading 1/1 (file index = 28)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_2904_6_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 29)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_2904_6_1.csv.gz
# Skipping...
# 2020-01
# Downloading 1/1 (file index = 26)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_1804_4_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 27)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2020/data_01bca733-0205-6d70-0042-fa0702a16be6_1804_4_1.csv.gz
# Skipping...
# 2019-12
# 2019-11
# Downloading 1/1 (file index = 24)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_204_3_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 25)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_204_3_1.csv.gz
# Skipping...
# 2019-10
# Downloading 1/1 (file index = 22)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_3004_3_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 23)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_3004_3_1.csv.gz
# Skipping...
# 2019-09
# Downloading 1/1 (file index = 19)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1604_2_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 20)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1604_2_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 21)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1604_2_2.csv.gz
# Skipping...
# 2019-08
# Downloading 1/1 (file index = 17)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1104_7_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 18)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1104_7_1.csv.gz
# Skipping...
# 2019-07
# Downloading 1/1 (file index = 14)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1104_0_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 15)
# Writing R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1104_0_1.csv.gz
# Please be patient. It may take a while...
#
# Downloading 1/1 (file index = 16)
# Writing R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1104_0_2.csv.gz
# Please be patient. It may take a while...
#
# 2019-06
# Downloading 1/1 (file index = 11)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1104_0_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 12)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1104_0_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 13)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1104_0_2.csv.gz
# Skipping...
# 2019-05
# Downloading 1/1 (file index = 9)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_2104_4_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 10)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_2104_4_1.csv.gz
# Skipping...
# 2019-04
# Downloading 1/1 (file index = 7)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_2204_7_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 8)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_2204_7_1.csv.gz
# Skipping...
# 2019-03
# Downloading 1/1 (file index = 4)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1004_1_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 5)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1004_1_1.csv.gz
# Skipping...
# Downloading 1/1 (file index = 6)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1004_1_2.csv.gz
# Skipping...
# 2019-02
# Downloading 1/1 (file index = 2)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_904_4_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 3)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_904_4_1.csv.gz
# Skipping...
# 2019-01
# Downloading 1/1 (file index = 0)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1604_1_0.csv.gz
# Skipping...
# Downloading 1/1 (file index = 1)
# File already exists: R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019/data_01bca733-0205-6d70-0042-fa0702a16be6_1604_1_1.csv.gz
# Skipping...
# 2018-12
# 2018-11
# 2018-10
# 2018-09
# 2018-08
# 2018-07
# 2018-06
# 2018-05
# 2018-04
# 2018-03
# 2018-02
# 2018-01

# %% [markdown]
# QC of Downloads

# %%
err_list_all = pd.DataFrame()
execfile(PATH_KIOSK_USER_PATTERNS_REPO / 'functions' /'compare_file_sizes.py')
files = pd.read_csv(PATH_KIOSK_USER_PATTERNS_REPO / 'data' / f'kupdat09b_pass_by retail store visits.csv')
for y in range(2024, 2017, -1):
    dest_dir = fr'R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/{y}'
    result = compare_file_sizes(dest_dir, files)
    df_result = pd.DataFrame(result)
    df_result['year'] = y
    err_list_all = pd.concat([err_list_all, df_result], ignore_index=True)
# Out:
# File size mismatch for data_01bca733-0205-6d70-0042-fa0702a16be6_1104_1_1.csv.gz: expected 394209143, got 371253093
# File size mismatch for data_01bca733-0205-6d70-0042-fa0702a16be6_1004_1_2.csv.gz: expected 203461736, got 128975065
# File size mismatch for data_01bca733-0205-6d70-0042-fa0702a16be6_404_4_1.csv.gz: expected 419470977, got 379840514
# File size mismatch for data_01bca733-0205-6d70-0042-fa0702a16be6_1104_0_2.csv.gz: expected 215442591, got 3228892

# %%
err_list_all
# Out:
#                                            file_name  \
# 0  data_01bca733-0205-6d70-0042-fa0702a16be6_1104...
# 1  data_01bca733-0205-6d70-0042-fa0702a16be6_1004...
# 2  data_01bca733-0205-6d70-0042-fa0702a16be6_404_...
# 3  data_01bca733-0205-6d70-0042-fa0702a16be6_1104...
#
#                                            file_path expected_size  \
# 0  R:/Global Diabetes Research Center/Patel/pass_...     394209143
# 1  R:/Global Diabetes Research Center/Patel/pass_...     203461736
# 2  R:/Global Diabetes Research Center/Patel/pass_...     419470977
# 3  R:/Global Diabetes Research Center/Patel/pass_...     215442591
#
#   actual_size  year
# 0   371253093  2024
# 1   128975065  2022
# 2   379840514  2022
# 3     3228892  2019

# %%
err_list_all.head()
# Out:
#                                            file_name  \
# 0  data_01bca733-0205-6d70-0042-fa0702a16be6_1104...
# 1  data_01bca733-0205-6d70-0042-fa0702a16be6_1004...
# 2  data_01bca733-0205-6d70-0042-fa0702a16be6_404_...
# 3  data_01bca733-0205-6d70-0042-fa0702a16be6_1104...
#
#                                            file_path expected_size  \
# 0  R:/Global Diabetes Research Center/Patel/pass_...     394209143
# 1  R:/Global Diabetes Research Center/Patel/pass_...     203461736
# 2  R:/Global Diabetes Research Center/Patel/pass_...     419470977
# 3  R:/Global Diabetes Research Center/Patel/pass_...     215442591
#
#   actual_size  year
# 0   371253093  2024
# 1   128975065  2022
# 2   379840514  2022
# 3     3228892  2019

# %%
from shutil import move

for y in range(2024, 2017, -1):
    error_dest_dir = fr'R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits - Error/{y}'
    os.makedirs(error_dest_dir, exist_ok=True)

    # Filter err_list_all to only include rows where year == y
    err_list_year = err_list_all[err_list_all['year'] == y]
    for file_path in err_list_year['file_path']:
        try:
            move(file_path, error_dest_dir)
        except Exception as e:
            print(f"Failed to move {file_path}: {e}")
# Out:
# Failed to move R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2024\data_01bca733-0205-6d70-0042-fa0702a16be6_1104_1_1.csv.gz: Destination path 'R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits - Error/2024\data_01bca733-0205-6d70-0042-fa0702a16be6_1104_1_1.csv.gz' already exists
# Failed to move R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022\data_01bca733-0205-6d70-0042-fa0702a16be6_1004_1_2.csv.gz: Destination path 'R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits - Error/2022\data_01bca733-0205-6d70-0042-fa0702a16be6_1004_1_2.csv.gz' already exists
# Failed to move R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2022\data_01bca733-0205-6d70-0042-fa0702a16be6_404_4_1.csv.gz: Destination path 'R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits - Error/2022\data_01bca733-0205-6d70-0042-fa0702a16be6_404_4_1.csv.gz' already exists
# Failed to move R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits/2019\data_01bca733-0205-6d70-0042-fa0702a16be6_1104_0_2.csv.gz: Destination path 'R:/Global Diabetes Research Center/Patel/pass_by/Retail Store Visits - Error/2019\data_01bca733-0205-6d70-0042-fa0702a16be6_1104_0_2.csv.gz' already exists
