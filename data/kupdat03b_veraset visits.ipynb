# %%
import sys
import os
from pathlib import Path
import pyarrow.parquet as pq
import pyarrow.dataset as ds
import pandas as pd
import matplotlib.pyplot as plt
sys.path.append(str(Path.cwd().parent))
from config import PATH_KIOSK_USER_PATTERNS_FOLDER, PATH_KIOSK_USER_PATTERNS_REPO, PATH_DATA_SHARING_FOLDER

# Example usage
kupdat03_path = PATH_DATA_SHARING_FOLDER /'DEWEY'
execfile(PATH_KIOSK_USER_PATTERNS_REPO / 'constants.py')
execfile(PATH_KIOSK_USER_PATTERNS_REPO / 'functions/extract_file_list.py')

# %%
import numpy as np
import deweydatapy as ddp

# Create date range from Jan 1, 2019 to June 30, 2025
dates = pd.date_range(start='2019-01-01', end='2025-06-30', freq='D')
df_dates = pd.DataFrame({'date': dates})
df_dates['is_weekday'] = df_dates['date'].dt.weekday < 5

# Add year and month columns for grouping
df_dates['year'] = df_dates['date'].dt.year
df_dates['month'] = df_dates['date'].dt.month

# Function to sample one weekday and one weekend per group
def sample_days(group):
    weekday = group[group['is_weekday']].sample(1, random_state=42) if group['is_weekday'].any() else pd.DataFrame()
    weekend = group[~group['is_weekday']].sample(1, random_state=42) if (~group['is_weekday']).any() else pd.DataFrame()
    return pd.concat([weekday, weekend])

# Apply sampling per year-month group
sampled = df_dates.groupby(['year', 'month'], group_keys=False).apply(sample_days).reset_index(drop=True)

sampled.head()
# Out:
# C:\Users\jvargh7\AppData\Local\Temp\ipykernel_16288\414929021.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled = df_dates.groupby(['year', 'month'], group_keys=False).apply(sample_days).reset_index(drop=True)
#         date  is_weekday  year  month
# 0 2019-01-22        True  2019      1
# 1 2019-01-06       False  2019      1
# 2 2019-02-01        True  2019      2
# 3 2019-02-03       False  2019      2
# 4 2019-03-01        True  2019      3

# %%
# data_endpoint = "https://app.deweydata.io/external-api/v3/products/c117bbd0-ed3a-4c05-8f3c-01ac4b12ef60/files"
data_endpoint = "https://app.deweydata.io/api/v1/external/data/fldr_8zme9bwbekydvezq"

# %%
# m = 12 # pending
for y in range(2024, 2018, -1):
    for m in range(11,0,-1):
        start = f"{y}-{m:02d}-01"
        if m == 2:
            end = f"{y}-{m:02d}-28" # doesn't account for leap years, but we are not going that far back
        elif m in [4, 6, 9, 11]:
            end = f"{y}-{m:02d}-30"
        else:
            end = f"{y}-{m:02d}-31"
        if pd.to_datetime(end) > pd.to_datetime('2025-05-31'):
            end = '2025-05-31'

        print(start + " to " + end)
        files, meta = extract_file_list(bulk_api_veraset_visits, data_endpoint, sd=start, ed=end)
        files.to_csv(PATH_KIOSK_USER_PATTERNS_REPO / 'data' / f'kupdat03b_veraset_visits_{y}_{m:02d}.csv', index=False)

        # Ensure 'partition_key' in files and 'date' in sampled are both datetime type
        files['partition_key_dt'] = pd.to_datetime(files['partition_key'])
        sampled['date_dt'] = pd.to_datetime(sampled['date'])

        # Perform inner join on 'partition_key' and 'date'
        merged = pd.merge(files, sampled, left_on='partition_key_dt', right_on='date_dt', how='inner')
        merged.to_csv(PATH_KIOSK_USER_PATTERNS_REPO / 'data' / f'kupdat03b_veraset visits after sampling_{y}_{m:02d}.csv', index=False)


        dest_dir = fr'R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/{y}/'
        os.makedirs(dest_dir, exist_ok=True)


        ddp.download_files(merged, dest_folder = dest_dir,   skip_exists= True)
# Out:
# 2024-12-01 to 2024-12-31
#
# Metadata summary ------------------------------------------------
# Total number of files: 240,709
# Total files size (MB): 11,456,926.18
# Date aggregation: DAY
# Date partition column: UTC_TIMESTAMP
# Data min available date: 2019-01-01
# Data max available date: 2025-05-31
# -----------------------------------------------------------------
#
# Collecting files information for page 1/154...
# Collecting files information for page 2/154...
# Collecting files information for page 3/154...
# Collecting files information for page 4/154...
# Collecting files information for page 5/154...
# Collecting files information for page 6/154...
# Collecting files information for page 7/154...
# Collecting files information for page 8/154...
# Collecting files information for page 9/154...
# Collecting files information for page 10/154...
# Collecting files information for page 11/154...
# Collecting files information for page 12/154...
# Collecting files information for page 13/154...
# Collecting files information for page 14/154...
# Collecting files information for page 15/154...
# Collecting files information for page 16/154...
# Collecting files information for page 17/154...
# Collecting files information for page 18/154...
# Collecting files information for page 19/154...
# Collecting files information for page 20/154...
# Collecting files information for page 21/154...
# Collecting files information for page 22/154...
# Collecting files information for page 23/154...
# Collecting files information for page 24/154...
# Collecting files information for page 25/154...
# Collecting files information for page 26/154...
# Collecting files information for page 27/154...
# Collecting files information for page 28/154...
# Collecting files information for page 29/154...
# Collecting files information for page 30/154...
# Collecting files information for page 31/154...
# Collecting files information for page 32/154...
# Collecting files information for page 33/154...
# Collecting files information for page 34/154...
# Collecting files information for page 35/154...
# Collecting files information for page 36/154...
# Collecting files information for page 37/154...
# Collecting files information for page 38/154...
# Collecting files information for page 39/154...
# Collecting files information for page 40/154...
# Collecting files information for page 41/154...
# Collecting files information for page 42/154...
# Collecting files information for page 43/154...
# Collecting files information for page 44/154...
# Collecting files information for page 45/154...
# Collecting files information for page 46/154...
# Collecting files information for page 47/154...
# Collecting files information for page 48/154...
# Collecting files information for page 49/154...
# Collecting files information for page 50/154...
# Collecting files information for page 51/154...
# Collecting files information for page 52/154...
# Collecting files information for page 53/154...
# Collecting files information for page 54/154...
# Collecting files information for page 55/154...
# Collecting files information for page 56/154...
# Collecting files information for page 57/154...
# Collecting files information for page 58/154...
# Collecting files information for page 59/154...
# Collecting files information for page 60/154...
# Collecting files information for page 61/154...
# Collecting files information for page 62/154...
# Collecting files information for page 63/154...
# Collecting files information for page 64/154...
# Collecting files information for page 65/154...
# Collecting files information for page 66/154...
# Collecting files information for page 67/154...
# Collecting files information for page 68/154...
# Collecting files information for page 69/154...
# Collecting files information for page 70/154...
# Collecting files information for page 71/154...
# Collecting files information for page 72/154...
# Collecting files information for page 73/154...
# Collecting files information for page 74/154...
# Collecting files information for page 75/154...
# Collecting files information for page 76/154...
# Collecting files information for page 77/154...
# Collecting files information for page 78/154...
# Collecting files information for page 79/154...
# Collecting files information for page 80/154...
# Collecting files information for page 81/154...
# Collecting files information for page 82/154...
# Collecting files information for page 83/154...
# Collecting files information for page 84/154...
# Collecting files information for page 85/154...
# Collecting files information for page 86/154...
# Collecting files information for page 87/154...
# Collecting files information for page 88/154...
# Collecting files information for page 89/154...
# Collecting files information for page 90/154...
# Collecting files information for page 91/154...
# Collecting files information for page 92/154...
# Collecting files information for page 93/154...
# Collecting files information for page 94/154...
# Collecting files information for page 95/154...
# Collecting files information for page 96/154...
# Collecting files information for page 97/154...
# Collecting files information for page 98/154...
# Collecting files information for page 99/154...
# Collecting files information for page 100/154...
# Collecting files information for page 101/154...
# Collecting files information for page 102/154...
# Collecting files information for page 103/154...
# Collecting files information for page 104/154...
# Collecting files information for page 105/154...
# Collecting files information for page 106/154...
# Collecting files information for page 107/154...
# Collecting files information for page 108/154...
# Collecting files information for page 109/154...
# Collecting files information for page 110/154...
# Collecting files information for page 111/154...
# Collecting files information for page 112/154...
# Collecting files information for page 113/154...
# Collecting files information for page 114/154...
# Collecting files information for page 115/154...
# Collecting files information for page 116/154...
# Collecting files information for page 117/154...
# Collecting files information for page 118/154...
# Collecting files information for page 119/154...
# Collecting files information for page 120/154...
# Collecting files information for page 121/154...
# Collecting files information for page 122/154...
# Collecting files information for page 123/154...
# Collecting files information for page 124/154...
# Collecting files information for page 125/154...
# Collecting files information for page 126/154...
# Collecting files information for page 127/154...
# Collecting files information for page 128/154...
# Collecting files information for page 129/154...
# Collecting files information for page 130/154...
# Collecting files information for page 131/154...
# Collecting files information for page 132/154...
# Collecting files information for page 133/154...
# Collecting files information for page 134/154...
# Collecting files information for page 135/154...
# Collecting files information for page 136/154...
# Collecting files information for page 137/154...
# Collecting files information for page 138/154...
# Collecting files information for page 139/154...
# Collecting files information for page 140/154...
# Collecting files information for page 141/154...
# Collecting files information for page 142/154...
# Collecting files information for page 143/154...
# Collecting files information for page 144/154...
# Collecting files information for page 145/154...
# Collecting files information for page 146/154...
# Collecting files information for page 147/154...
# Collecting files information for page 148/154...
# Collecting files information for page 149/154...
# Collecting files information for page 150/154...
# Collecting files information for page 151/154...
# Collecting files information for page 152/154...
# Collecting files information for page 153/154...
# Collecting files information for page 154/154...
# Files information collection completed.
#
# Files information summary ---------------------------------------
# Total number of pages: 154
# Total number of files: 7,680
# Total files size (MB): 228,078.97
# Average single file size (MB): 29.69
# Date partition column: UTC_TIMESTAMP
# Expires at: 2025-07-14T21:19:26.292635+00:00
# -----------------------------------------------------------------
# Downloading 1/512 (file index = 256)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00000-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1149-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 2/512 (file index = 257)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00001-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1237-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 3/512 (file index = 258)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00002-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1346-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 4/512 (file index = 259)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00003-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1260-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 5/512 (file index = 260)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00004-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1221-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 6/512 (file index = 261)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00005-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1164-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 7/512 (file index = 262)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00006-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1376-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 8/512 (file index = 263)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00007-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1239-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 9/512 (file index = 264)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00008-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1266-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 10/512 (file index = 265)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00009-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1370-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 11/512 (file index = 266)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00010-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1236-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 12/512 (file index = 267)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00011-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1273-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 13/512 (file index = 268)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00012-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1156-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 14/512 (file index = 269)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00013-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1146-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 15/512 (file index = 270)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00014-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1240-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 16/512 (file index = 271)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00015-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1180-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 17/512 (file index = 272)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00016-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1316-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 18/512 (file index = 273)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00017-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1212-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 19/512 (file index = 274)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00018-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1334-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 20/512 (file index = 275)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00019-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1265-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 21/512 (file index = 276)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00020-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1144-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 22/512 (file index = 277)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00021-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-1272-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 23/512 (file index = 278)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00022-tid-3900123142972219622-a0b40fad-b26d-4831-ac7c-5f67350cf951-

# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00246-tid-8652174137021009957-2c089c26-1b32-4852-aea1-853beaa9c712-12637-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 504/512 (file index = 7159)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00247-tid-8652174137021009957-2c089c26-1b32-4852-aea1-853beaa9c712-12638-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 505/512 (file index = 7160)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00248-tid-8652174137021009957-2c089c26-1b32-4852-aea1-853beaa9c712-12639-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 506/512 (file index = 7161)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00249-tid-8652174137021009957-2c089c26-1b32-4852-aea1-853beaa9c712-12640-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 507/512 (file index = 7162)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00250-tid-8652174137021009957-2c089c26-1b32-4852-aea1-853beaa9c712-12641-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 508/512 (file index = 7163)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00251-tid-8652174137021009957-2c089c26-1b32-4852-aea1-853beaa9c712-12642-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 509/512 (file index = 7164)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00252-tid-8652174137021009957-2c089c26-1b32-4852-aea1-853beaa9c712-12643-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 510/512 (file index = 7165)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00253-tid-8652174137021009957-2c089c26-1b32-4852-aea1-853beaa9c712-12644-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 511/512 (file index = 7166)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00254-tid-8652174137021009957-2c089c26-1b32-4852-aea1-853beaa9c712-12645-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# Downloading 512/512 (file index = 7167)
# Writing R:/Global Diabetes Research Center/Patel/Veraset/Sampled Visit Dates/2024/part-00255-tid-8652174137021009957-2c089c26-1b32-4852-aea1-853beaa9c712-12646-1-c000.snappy.parquet
# Please be patient. It may take a while...
#
# 2024-11-01 to 2024-11-30
#
# Metadata summary ------------------------------------------------
# Total number of files: 240,709
# Total files size (MB): 11,456,926.18
# Date aggregation: DAY
# Date partition column: UTC_TIMESTAMP
# Data min available date: 2019-01-01
# Data max available date: 2025-05-31
# -----------------------------------------------------------------
#
# Collecting files information for page 1/149...
# Collecting files information for page 2/149...
# Collecting files information for page 3/149...
# Collecting files information for page 4/149...
# Collecting files information for page 5/149...
# Collecting files information for page 6/149...
# Collecting files information for page 7/149...
# Collecting files information for page 8/149...
# Collecting files information for page 9/149...
# Collecting files information for page 10/149...
# Collecting files information for page 11/149...
# Collecting files information for page 12/149...
# Collecting files information for page 13/149...
# Collecting files information for page 14/149...
# Collecting files information for page 15/149...
# Collecting files information for page 16/149...
# Collecting files information for page 17/149...
# Collecting files information for page 18/149...
# Collecting files information for page 19/149...
# Collecting files information for page 20/149...
# Collecting files information for page 21/149...
# Collecting files information for page 22/149...
# Collecting files information for page 23/149...
# Collecting files information for page 24/149...
# Collecting files information for page 25/149...
# Collecting files information for page 26/149...
# Collecting files information for page 27/149...
# Collecting files information for page 28/149...
# Collecting files information for page 29/149...
# Collecting files information for page 30/149...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 14
#      11     end = '2025-05-31'
#      13 print(start + " to " + end)
# ---> 14 files, meta = extract_file_list(bulk_api_veraset_visits, data_endpoint, sd=start, ed=end)
#      15 files.to_csv(PATH_KIOSK_USER_PATTERNS_REPO / 'data' / f'kupdat03b_veraset_visits_{y}_{m:02d}.csv', index=False)
#      17 # Ensure 'partition_key' in files and 'date' in sampled are both datetime type
#
# File C:\code\external\kiosk_user_patterns\functions\extract_file_list.py:15, in extract_file_list(api_key, pp_, sd, ed)
#      10 def extract_file_list(api_key, pp_,sd=None, ed=None):
#      11     # https://docs.deweydata.io/docs/api-access
#      14     meta_data = ddp.get_meta(apikey = api_key, dataset_path = pp_) # returns a dataframe with meta information
# ---> 15     file_list = ddp.get_file_list(apikey = api_key, dataset_path = pp_,start_date=sd, end_date=ed)
#      17     return file_list, meta_data
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\site-packages\deweydatapy\download.py:250, in get_file_list(apikey, dataset_path, start_page, end_page, start_date, end_date, meta, print_info)
#     233 def get_file_list(apikey, dataset_path, start_page=1, end_page=float('inf'),
#     234                   start_date=None, end_date=None,
#     235                   meta=None,
#     236                   print_info=True):
#     237     """
#     238     Collects the file list information from data server.
#     239
#    (...)
#     247     :return: A DataFrame object contains files information.
#     248     """
# --> 250     files_df, selection_meta, pages_meta = get_file_list_full(apikey, dataset_path,
#     251                                                         start_page, end_page,
#     252                                                         start_date, end_date,
#     253                                                         meta,
#     254                                                         print_info)
#     256     return files_df
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\site-packages\deweydatapy\download.py:149, in get_file_list_full(apikey, dataset_path, start_page, end_page, start_date, end_date, meta, print_info)
#     145     params_ = {'page': page,
#     146                'partition_key_after': start_date,
#     147                'partition_key_before': end_date}
#     148 try:
# --> 149     response = requests.get(url=dataset_path,
#     150                             params=params_,
#     151                             headers={'X-API-KEY': apikey,
#     152                                      'accept': 'application/json'})
#     153     response.raise_for_status()
#     154 except Exception as e:
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\jvargh7\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:
