# %% [markdown]
# | Code      | Table   | Category                        | Group                              | Universe    | Type          | Description                        | Universe    | Total | Device Description                                         | Device Type                                                        | Notes                                                        |
# |-----------|---------|---------------------------------|------------------------------------|-------------|---------------|-------------------------------------|-------------|-------|------------------------------------------------------------|---------------------------------------------------------------------|--------------------------------------------------------------|
# | B28001e1  | B28001  | Types Of Computers In Household | Telephone Computer and Internet Access | Households  | Estimate      | TYPES OF COMPUTERS IN HOUSEHOLD     | Households  | Total | NA                                                         | NA                                                                  | NA                                                           |
# | B28001e2  | B28001  | Types Of Computers In Household | Telephone Computer and Internet Access | Households  | Estimate      | TYPES OF COMPUTERS IN HOUSEHOLD     | Households  | Total | Has one or more types of computing devices                  | NA                                                                  | NA                                                           |
# | B28001e3  | B28001  | Types Of Computers In Household | Telephone Computer and Internet Access | Households  | Estimate      | TYPES OF COMPUTERS IN HOUSEHOLD     | Households  | Total | Has one or more types of computing devices                  | Desktop or laptop                                                    | NA                                                           |
# | B28001e4  | B28001  | Types Of Computers In Household | Telephone Computer and Internet Access | Households  | Estimate      | TYPES OF COMPUTERS IN HOUSEHOLD     | Households  | Total | Has one or more types of computing devices                  | Desktop or laptop                                                    | Desktop or laptop with no other type of computing device     |
# | B28001e5  | B28001  | Types Of Computers In Household | Telephone Computer and Internet Access | Households  | Estimate      | TYPES OF COMPUTERS IN HOUSEHOLD     | Households  | Total | Has one or more types of computing devices                  | Smartphone                                                           | NA                                                           |
# | B28001e6  | B28001  | Types Of Computers In Household | Telephone Computer and Internet Access | Households  | Estimate      | TYPES OF COMPUTERS IN HOUSEHOLD     | Households  | Total | Has one or more types of computing devices                  | Smartphone                                                           | Smartphone with no other type of computing device            |
# | B28001e7  | B28001  | Types Of Computers In Household | Telephone Computer and Internet Access | Households  | Estimate      | TYPES OF COMPUTERS IN HOUSEHOLD     | Households  | Total | Has one or more types of computing devices                  | Tablet or other portable wireless computer                           | NA                                                           |
# | B28001e8  | B28001  | Types Of Computers In Household | Telephone Computer and Internet Access | Households  | Estimate      | TYPES OF COMPUTERS IN HOUSEHOLD     | Households  | Total | Has one or more types of computing devices                  | Tablet or other portable wireless computer                           | Tablet or other portable wireless computer with no other type of computing device |
# | B28001e9  | B28001  | Types Of Computers In Household | Telephone Computer and Internet Access | Households  | Estimate      | TYPES OF COMPUTERS IN HOUSEHOLD     | Households  | Total | Has one or more types of computing devices                  | Other computer                                                       | NA                                                           |
# | B28001e10 | B28001  | Types Of Computers In Household | Telephone Computer and Internet Access | Households  | Estimate      | TYPES OF COMPUTERS IN HOUSEHOLD     | Households  | Total | Has one or more types of computing devices                  | Other computer                                                       | Other computer with no other type of computing device        |
# | B28001e11 | B28001  | Types Of Computers In Household | Telephone Computer and Internet Access | Households  | Estimate      | TYPES OF COMPUTERS IN HOUSEHOLD     | Households  | Total | No Computer                                                | NA                                                                  | NA                                                           |
# | B28005e1   | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | NA                                                        | NA                                                                  | NA                                                           |
# | B28005e2   | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | Under 18 years                                             | NA                                                                     | NA                                                           |
# | B28005e3   | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | Under 18 years                                             | Has a computer                                                        | NA                                                           |
# | B28005e4   | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | Under 18 years                                             | Has a computer                                                        | With dial-up Internet subscription alone                     |
# | B28005e5   | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | Under 18 years                                             | Has a computer                                                        | With a broadband Internet subscription                      |
# | B28005e6   | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | Under 18 years                                             | Has a computer                                                        | Without an Internet subscription                             |
# | B28005e7   | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | Under 18 years                                             | No computer                                                           | NA                                                           |
# | B28005e8   | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | 18 to 64 years                                             | NA                                                                     | NA                                                           |
# | B28005e9   | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | 18 to 64 years                                             | Has a computer                                                        | NA                                                           |
# | B28005e10  | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | 18 to 64 years                                             | Has a computer                                                        | With dial-up Internet subscription alone                     |
# | B28005e11  | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | 18 to 64 years                                             | Has a computer                                                        | With a broadband Internet subscription                      |
# | B28005e12  | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | 18 to 64 years                                             | Has a computer                                                        | Without an Internet subscription                             |
# | B28005e13  | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | 18 to 64 years                                             | No computer                                                           | NA                                                           |
# | B28005e14  | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | 65 years and over                                          | NA                                                                     | NA                                                           |
# | B28005e15  | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | 65 years and over                                          | Has a computer                                                        | NA                                                           |
# | B28005e16  | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | 65 years and over                                          | Has a computer                                                        | With dial-up Internet subscription alone                     |
# | B28005e17  | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | 65 years and over                                          | Has a computer                                                        | With a broadband Internet subscription                      |
# | B28005e18  | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | 65 years and over                                          | Has a computer                                                        | Without an Internet subscription                             |
# | B28005e19  | B28005  | Age By Presence Of A Computer And Types Of Internet Subscription In Household | Age and Sex, Telephone Computer and Internet Access | Population in Households | Estimate      | AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | 65 years and over                                          | No computer                                                           | NA                                                           |
# | B28008e1  | B28008  | Presence Of A Computer And Type Of Internet Subscription In Household | Telephone Computer and Internet Access | Population in Households | Estimate | PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | NA | NA | NA |
# | B28008e2  | B28008  | Presence Of A Computer And Type Of Internet Subscription In Household | Telephone Computer and Internet Access | Population in Households | Estimate | PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | Has a computer | NA | NA |
# | B28008e3  | B28008  | Presence Of A Computer And Type Of Internet Subscription In Household | Telephone Computer and Internet Access | Population in Households | Estimate | PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | Has a computer | With dial-up Internet subscription alone | NA |
# | B28008e4  | B28008  | Presence Of A Computer And Type Of Internet Subscription In Household | Telephone Computer and Internet Access | Population in Households | Estimate | PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | Has a computer | With a broadband subscription | NA |
# | B28008e5  | B28008  | Presence Of A Computer And Type Of Internet Subscription In Household | Telephone Computer and Internet Access | Population in Households | Estimate | PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | Has a computer | With a broadband subscription | With a fixed broadband Internet subscription |
# | B28008e6  | B28008  | Presence Of A Computer And Type Of Internet Subscription In Household | Telephone Computer and Internet Access | Population in Households | Estimate | PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | Has a computer | With a broadband subscription | With a fixed broadband Internet subscription, With a cellular data plan |
# | B28008e7  | B28008  | Presence Of A Computer And Type Of Internet Subscription In Household | Telephone Computer and Internet Access | Population in Households | Estimate | PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | Has a computer | With a broadband subscription | With a fixed broadband Internet subscription, Without a cellular data plan |
# | B28008e8  | B28008  | Presence Of A Computer And Type Of Internet Subscription In Household | Telephone Computer and Internet Access | Population in Households | Estimate | PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | Has a computer | With a broadband subscription | Cellular data plan alone or with dial-up |
# | B28008e9  | B28008  | Presence Of A Computer And Type Of Internet Subscription In Household | Telephone Computer and Internet Access | Population in Households | Estimate | PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | Has a computer | Without Internet subscription | NA |
# | B28008e10 | B28008  | Presence Of A Computer And Type Of Internet Subscription In Household | Telephone Computer and Internet Access | Population in Households | Estimate | PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD | Population in Households | Total | No Computer | NA | NA |
# | B28010e1  | B28010  | Computers In Household| Telephone Computer and Internet Access | Households  | Estimate  | COMPUTERS IN HOUSEHOLD     | Households  | Total | NA                                                         | NA                                                                  | NA                                                           |
# | B28010e2  | B28010  | Computers In Household| Telephone Computer and Internet Access | Households  | Estimate  | COMPUTERS IN HOUSEHOLD     | Households  | Total | Has one or more types of computing devices                  | NA                                                                  | NA                                                           |
# | B28010e3  | B28010  | Computers In Household| Telephone Computer and Internet Access | Households  | Estimate  | COMPUTERS IN HOUSEHOLD     | Households  | Total | Has one or more types of computing devices                  | Desktop or laptop                                                   | NA                                                           |
# | B28010e4  | B28010  | Computers In Household| Telephone Computer and Internet Access | Households  | Estimate  | COMPUTERS IN HOUSEHOLD     | Households  | Total | Has one or more types of computing devices                  | Desktop or laptop                                                   | Desktop or laptop alone                                       |
# | B28010e5  | B28010  | Computers In Household| Telephone Computer and Internet Access | Households  | Estimate  | COMPUTERS IN HOUSEHOLD     | Households  | Total | Has one or more types of computing devices                  | Smartphone tablet or other portable wireless computer or other computer | NA                                                           |
# | B28010e6  | B28010  | Computers In Household| Telephone Computer and Internet Access | Households  | Estimate  | COMPUTERS IN HOUSEHOLD     | Households  | Total | Has one or more types of computing devices                  | Smartphone tablet or other portable wireless computer or other computer | Smartphone tablet or other portable wireless computer or other computer no desktop or laptop |
# | B28010e7  | B28010  | Computers In Household| Telephone Computer and Internet Access | Households  | Estimate  | COMPUTERS IN HOUSEHOLD     | Households  | Total | No Computer                                                | NA                                                                  | NA                                                           |

# %%
import sys
from pathlib import Path
import pyarrow.parquet as pq
import pyarrow.dataset as ds
import pandas as pd

sys.path.append(str(Path.cwd().parent))
from config import PATH_KIOSK_USER_PATTERNS_FOLDER, PATH_KIOSK_USER_PATTERNS_REPO, PATH_SSD_CENSUS_FOLDER

# %%
# Extract codes from the markdown table
codes = ["B28001e1", "B28001e2", "B28001e3", "B28001e4", "B28001e5", "B28001e6", 
         "B28001e7", "B28001e8", "B28001e9", "B28001e10", "B28001e11",
         "B28005e1", "B28005e2", "B28005e3", "B28005e4", "B28005e5", "B28005e6", "B28005e7",
         "B28005e8", "B28005e9", "B28005e10", "B28005e11", "B28005e12", "B28005e13",
         "B28005e14", "B28005e15", "B28005e16", "B28005e17", "B28005e18", "B28005e19",
         "B28008e1", "B28008e2", "B28008e3", "B28008e4", "B28008e5", "B28008e6", 
         "B28008e7", "B28008e8", "B28008e9", "B28008e10",
         "B28010e1", "B28010e2", "B28010e3", "B28010e4", "B28010e5", "B28010e6", "B28010e7"]

# Define cols for reading data
cols = ["census_block_group"] + codes

cbg_b28 = pd.read_csv(
    PATH_SSD_CENSUS_FOLDER / "safegraph_open_census_data_2020/data/cbg_b28.csv",
    dtype=str,
    usecols=cols
)

cbg_b28["state_fips"] = cbg_b28["census_block_group"].str[:2]
cbg_b28["county_fips"] = cbg_b28["census_block_group"].str[2:5]


cbg_geographic_data = pd.read_csv(
    PATH_SSD_CENSUS_FOLDER / "safegraph_open_census_data_2020/metadata/cbg_geographic_data.csv",
    dtype=str
)

cbg_fips_codes = pd.read_csv(
    PATH_SSD_CENSUS_FOLDER / "safegraph_open_census_data_2020/metadata/cbg_fips_codes.csv",
    dtype=str
)

cbg_b28_merged = cbg_b28.merge(
    cbg_fips_codes,
    on=["state_fips", "county_fips"],
    how="left"
).merge(
    cbg_geographic_data,
    on="census_block_group",
    how="left"
)
# Out:
#   census_block_group B28001e1 B28001e2 B28001e3 B28001e4 B28001e5 B28001e6  \
# 0       010010201001      290      241      168        6      233       34
# 1       010010201002      403      354      347       17      337        7
# 2       010010202001      227      181      149        0      178       12
# 3       010010202002      346      323      200       12      304       62
# 4       010010203001     1034      999      842       17      950      112
#
#   B28001e7 B28001e8 B28001e9  ... B28010e7 state_fips county_fips state  \
# 0      149        2        0  ...       49         01         001    AL
# 1      274        0       12  ...       49         01         001    AL
# 2      146        0       10  ...       46         01         001    AL
# 3      168        0        0  ...       23         01         001    AL
# 4      618        6        7  ...       35         01         001    AL
#
#            county class_code amount_land amount_water    latitude    longitude
# ...

# %%
pd.set_option('display.max_columns', None)  # Show all columns in the DataFrame
cbg_b28_merged.head()
# Out:
#   census_block_group B28001e1 B28001e2 B28001e3 B28001e4 B28001e5 B28001e6  \
# 0       010010201001      290      241      168        6      233       34
# 1       010010201002      403      354      347       17      337        7
# 2       010010202001      227      181      149        0      178       12
# 3       010010202002      346      323      200       12      304       62
# 4       010010203001     1034      999      842       17      950      112
#
#   B28001e7 B28001e8 B28001e9 B28001e10 B28001e11 B28005e1 B28005e2 B28005e3  \
# 0      149        2        0         0        49      674      100      100
# 1      274        0       12         0        49     1267      315      315
# 2      146        0       10         0        46      706      248      248
# 3      168        0        0         0        23      839       77       77
# 4      618        6        7         0        35     2912      739      737
#
# ...

# %%
cbg_b28_updated = (cbg_b28_merged
                   .assign(prop_ind_cellular_total = lambda x: (pd.to_numeric(x['B28008e6']) + pd.to_numeric(x['B28008e8'])) / pd.to_numeric(x['B28008e1']))
                   .assign(prop_ind_cellular_broadband = lambda x: (pd.to_numeric(x['B28008e6']) + pd.to_numeric(x['B28008e8'])) / pd.to_numeric(x['B28008e4']))
                   .assign(prop_ind_broadband_total = lambda x: pd.to_numeric(x['B28008e4']) / pd.to_numeric(x['B28008e1']))
                   .assign(prop_hh_smartphone_total = lambda x: pd.to_numeric(x['B28001e5']) / pd.to_numeric(x['B28001e1']))
                   .assign(prop_hh_onlysmartphone_smartphone = lambda x: pd.to_numeric(x['B28010e6']) / pd.to_numeric(x['B28001e5'])))

cbg_b28_updated.to_csv(PATH_KIOSK_USER_PATTERNS_FOLDER / "working/processed/kupdat04_safegraph census data.csv", index=False)
